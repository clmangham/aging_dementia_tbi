# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/DescriptionOfStains.csv')
df.head()
# Out:
#                 api_class_name                internal_name
# 0            ApiTbiDonorMetric                   ihc_a_beta  \
# 1  TbiNonquantifiedImageStains                 h_e_lfb_ffpe
# 2            ApiTbiDonorMetric                    ihc_a_syn
# 3            ApiTbiDonorDetail  root_specimen_external_name
# 4            ApiTbiDonorMetric              ifn_g_pg_per_mg
#
#                                          description  treatment_id
# 0  Percentage of area covered by Aβ immunreactivi...   300239718.0  \
# 1  Hematoxylin identifies cell nuclei; Eosin stai...   471133394.0
# 2  Percentage of area covered by α-synuclein immu...   300239725.0
# 3                                  UW autopsy number           NaN
# 4  A prototype pro-inflammatory cytokine, critica...           NaN
#
#                                            full_name  gene_id
# 0  Beta-amyloid  immunohistochemistry (fresh froz...      NaN  \
# 1       Hematoxylin and eosin-Luxol Fast Blue stains      NaN
# ...

# %%
df['race'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/mads/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mads/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/mads/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'race'
#
# ...

# %%
df['act_demented'].value_counts()
# Out:
# act_demented
# No Dementia    57
# Dementia       50
# Name: count, dtype: int64

# %%
quants_df = pd.read_csv('ProteinAndPathologyQuantifications.csv')
quants_df.head()
# Out:
#     donor_id  donor_name  structure_id structure_acronym  ihc_a_syn
# 0  309335467  H14.09.030         10557               FWM   0.000078  \
# 1  309335480  H14.09.043         10208               PCx   0.000063
# 2  309335493  H14.09.056         10557               FWM   0.000064
# 3  326765668  H14.09.081         10557               FWM   0.000049
# 4  326765668  H14.09.081         10235               TCx   0.000080
#
#    ihc_tau2_ffpe  ihc_at8_ffpe   ihc_at8  ihc_ptdp_43_ffpe  ihc_a_beta_ffpe
# 0       0.002358      0.001137  0.000110          0.001259         0.008335  \
# 1       0.002762      0.001272  0.000164          0.002354         0.005047
# 2       0.003468      0.013787  0.016023          0.001708         0.007365
# 3       0.003035      0.001707  0.000137          0.001729         0.004046
# 4       0.002088      0.004489  0.000062          0.001513         0.015809
#
#    ...  il_4_pg_per_mg  rantes_pg_per_mg  ab40_pg_per_mg  a_syn_pg_per_mg
# ...

# %%
pd.read_csv('gene_expression_matrix_2016-03-03/columns-samples.csv')
# Out:
#      rnaseq_profile_id   donor_id  donor_name  specimen_id      specimen_name
# 0            488395315  309335467  H14.09.030    309357843  H14.09.030.TCx.01  \
# 1            496100277  309335441  H14.09.004    309357624  H14.09.004.PCx.01
# 2            496100278  309335438  H14.09.001    309357596  H14.09.001.PCx.01
# 3            496100279  309335438  H14.09.001    309357599  H14.09.001.TCx.01
# 4            496100281  309335439  H14.09.002    309357603  H14.09.002.HIP.01
# ..                 ...        ...         ...          ...                ...
# 372          496100667  467056391  H15.09.103    467179071  H15.09.103.TCx.01
# 373          496100669  467056391  H15.09.103    467179068  H15.09.103.PCx.01
# 374          496100670  467056406  H15.09.107    467179104  H15.09.107.TCx.01
# 375          496100671  467056391  H15.09.103    467179065  H15.09.103.HIP.01
# 376          496100672  467056407  H15.09.108    467179110  H15.09.108.PCx.01
#
# ...

# %% [markdown]
# ## Heading

# %% [markdown]
# ### Added this to test branching

# %%
 # Check my math! (Code review test)

def check_this_code():
    new_var = 2**4 
    other_var = new_var / 2

    return other_var*3

# %%
check_this_code()
# Out:
# 24.0
