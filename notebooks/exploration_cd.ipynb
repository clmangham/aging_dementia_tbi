# %% [markdown]
# import pandas

# %%
import pandas as pd
import os
import plotly

# %%
os.getcwd()
# Out:
# 'c:\\Users\\dyeca\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
donor=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\DonorInformation.csv')
donor
# Out:
#       donor_id        name    age sex apo_e4_allele  education_years  \
# 0    326765665  H14.09.078     87   M             N               16
# 1    326765656  H14.09.069  95-99   M             N               17
# 2    326765654  H14.09.067     85   M             Y               10
# 3    467056391  H15.09.103  90-94   F             N               11
# 4    309335447  H14.09.010   100+   M             Y               16
# ..         ...         ...    ...  ..           ...              ...
# 102  309335458  H14.09.021     88   M             N               12
# 103  309335462  H14.09.025     84   M             N               16
# 104  309335454  H14.09.017     79   M             N               16
# 105  309335486  H14.09.049  95-99   M             N               21
# 106  309335442  H14.09.005  90-94   F             Y               14
#
#      age_at_first_tbi longest_loc_duration  cerad  num_tbi_w_loc  \
# 0                   0       Unknown or N/A      0              0
# ...

# %%
quant=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\ProteinAndPathologyQuantifications.csv')
quant
# Out:
#       donor_id  donor_name  structure_id structure_acronym  ihc_a_syn  \
# 0    309335467  H14.09.030         10557               FWM   0.000078
# 1    309335480  H14.09.043         10208               PCx   0.000063
# 2    309335493  H14.09.056         10557               FWM   0.000064
# 3    326765668  H14.09.081         10557               FWM   0.000049
# 4    326765668  H14.09.081         10235               TCx   0.000080
# ..         ...         ...           ...               ...        ...
# 372  326765653  H14.09.066         10208               PCx   0.000046
# 373  309335452  H14.09.015         10294               HIP   0.000089
# 374  309335489  H14.09.052         10294               HIP   0.000066
# 375  309335458  H14.09.021         10208               PCx   0.000793
# 376  309335494  H14.09.057         10235               TCx   0.000079
#
#      ihc_tau2_ffpe  ihc_at8_ffpe   ihc_at8  ihc_ptdp_43_ffpe  ihc_a_beta_ffpe  \
# ...

# %%
tbidata=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\tbi_data_files.csv')
tbidata
# Out:
#       donor_id  donor_name  specimen_id      specimen_name   rna_well  \
# 0    309335438  H14.09.001    309357595  H14.09.001.HIP.05  320630832
# 1    309335438  H14.09.001    309357596  H14.09.001.PCx.01  320630834
# 2    309335438  H14.09.001    309357596  H14.09.001.PCx.01  320630836
# 3    309335438  H14.09.001    309357599  H14.09.001.TCx.01  320630838
# 4    309335439  H14.09.002    309357603  H14.09.002.HIP.01  320630842
# ..         ...         ...          ...                ...        ...
# 372  467056408  H15.09.109    467179122  H15.09.109.TCx.01  482655796
# 373  467056409  H15.09.110    467179125  H15.09.110.HIP.01  482655798
# 374  467056409  H15.09.110    467179128  H15.09.110.PCx.01  482655800
# 375  467056409  H15.09.110    467179128  H15.09.110.PCx.01  482655802
# 376  467056409  H15.09.110    467179131  H15.09.110.TCx.01  482655804
#
#      rna_integrity_number  structure_id structure_acronym  \
# 0                     7.3         10294               HIP
# ...

# %%
desc=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\DescriptionOfStains.csv')
desc
# Out:
#                  api_class_name                internal_name  \
# 0             ApiTbiDonorMetric                   ihc_a_beta
# 1   TbiNonquantifiedImageStains                 h_e_lfb_ffpe
# 2             ApiTbiDonorMetric                    ihc_a_syn
# 3             ApiTbiDonorDetail  root_specimen_external_name
# 4             ApiTbiDonorMetric              ifn_g_pg_per_mg
# ..                          ...                          ...
# 57  TbiNonquantifiedImageStains                     ish_gfap
# 58            ApiTbiDonorDetail                        braak
# 59            ApiTbiDonorMetric              tnf_a_pg_per_mg
# 60            ApiTbiDonorDetail                     hispanic
# 61            ApiTbiDonorDetail             age_at_first_tbi
#
#                                           description  treatment_id  \
# 0   Percentage of area covered by Aβ immunreactivi...   300239718.0
# 1   Hematoxylin identifies cell nuclei; Eosin stai...   471133394.0
# ...

# %%
rna_norm=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\gene_expression_matrix_2016-03-03\\fpkm_table_normalized.csv')
rna_norm
# Out:
#        gene_id \ rnaseq_profile_id   488395315   496100277   496100278  \
# 0                        499304660    0.655725    0.095143    0.000000
# 1                        499304661    4.526404    8.855850    4.868456
# 2                        499304662    0.000000    0.000000    0.000000
# 3                        499304663    0.000000    0.000000    0.000000
# 4                        499304664    0.039654    0.016492    0.000000
# ...                            ...         ...         ...         ...
# 50276                    499355059   59.293828   24.446436   37.608601
# 50277                    499355060    0.000000    0.000000    3.323079
# 50278                    499355061  409.916660  375.295129  358.011161
# 50279                    499355062    0.000000    0.000000    0.000000
# 50280                    499355063    0.000000    0.000000    0.000000
#
#         496100279   496100281   496100283   496100284   496100285   496100287  \
# ...

# %%
rna_norm.columns
# Out:
# Index(['gene_id \ rnaseq_profile_id', '488395315', '496100277', '496100278',
#        '496100279', '496100281', '496100283', '496100284', '496100285',
#        '496100287',
#        ...
#        '496100661', '496100663', '496100664', '496100665', '496100666',
#        '496100667', '496100669', '496100670', '496100671', '496100672'],
#       dtype='object', length=378)

# %%
rna_norm_melt=pd.melt(rna_norm, id_vars='gene_id \ rnaseq_profile_id')

rna_norm_melt['variable']=rna_norm_melt['variable'].astype('int64')

# %%
genes=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\gene_expression_matrix_2016-03-03\\rows-genes.csv')
genes
# Out:
#          gene_id chromosome  gene_entrez_id gene_symbol  \
# 0      499304660          1       100287102     DDX11L1
# 1      499304661          1          653635      WASH7P
# 2      499304662          1       102466751   MIR6859-1
# 3      499304663          1       100302278   MIR1302-2
# 4      499304664          1          645520     FAM138A
# ...          ...        ...             ...         ...
# 50276  499355059         MT            4541         ND6
# 50277  499355060         MT            4556        TRNE
# 50278  499355061         MT            4519        CYTB
# 50279  499355062         MT            4576        TRNT
# 50280  499355063         MT            4571        TRNP
#
#                                                gene_name
# 0      DEAD/H (Asp-Glu-Ala-Asp/His) box helicase 11 l...
# 1                WAS protein family homolog 7 pseudogene
# 2                                        microRNA 6859-1
# 3                                        microRNA 1302-2
# ...

# %%
rna_norm_melt.dtypes
# Out:
# gene_id \ rnaseq_profile_id      int64
# variable                         int64
# value                          float64
# dtype: object

# %%
rna_df=rna_norm_melt.merge(genes,how='left', left_on='gene_id \ rnaseq_profile_id',right_on='gene_id')

# %%
rna_df
# Out:
#           gene_id \ rnaseq_profile_id   variable       value    gene_id  \
# 0                           499304660  488395315    0.655725  499304660
# 1                           499304661  488395315    4.526404  499304661
# 2                           499304662  488395315    0.000000  499304662
# 3                           499304663  488395315    0.000000  499304663
# 4                           499304664  488395315    0.039654  499304664
# ...                               ...        ...         ...        ...
# 18955932                    499355059  496100672   41.339535  499355059
# 18955933                    499355060  496100672    1.962493  499355060
# 18955934                    499355061  496100672  383.616738  499355061
# 18955935                    499355062  496100672    0.000000  499355062
# 18955936                    499355063  496100672    0.000000  499355063
#
#          chromosome  gene_entrez_id gene_symbol  \
# 0                 1       100287102     DDX11L1
# ...

# %%
samples=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\gene_expression_matrix_2016-03-03\\columns-samples.csv')
samples
# Out:
#      rnaseq_profile_id   donor_id  donor_name  specimen_id      specimen_name  \
# 0            488395315  309335467  H14.09.030    309357843  H14.09.030.TCx.01
# 1            496100277  309335441  H14.09.004    309357624  H14.09.004.PCx.01
# 2            496100278  309335438  H14.09.001    309357596  H14.09.001.PCx.01
# 3            496100279  309335438  H14.09.001    309357599  H14.09.001.TCx.01
# 4            496100281  309335439  H14.09.002    309357603  H14.09.002.HIP.01
# ..                 ...        ...         ...          ...                ...
# 372          496100667  467056391  H15.09.103    467179071  H15.09.103.TCx.01
# 373          496100669  467056391  H15.09.103    467179068  H15.09.103.PCx.01
# 374          496100670  467056406  H15.09.107    467179104  H15.09.107.TCx.01
# 375          496100671  467056391  H15.09.103    467179065  H15.09.103.HIP.01
# 376          496100672  467056407  H15.09.108    467179110  H15.09.108.PCx.01
#
# ...

# %% [markdown]
# CONTAINER TEST

# %%
import tensorflow as tf
# Out:
# 2023-10-21 22:29:31.526793: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-21 22:29:31.828070: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-21 22:29:31.828522: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-21 22:29:31.829798: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-21 22:29:32.019883: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
weights=pd.read_csv('C:\\Users\\dyeca\\OneDrive\\Documents\\capstone\\aging_dementia_tbi\\data\\group_weights.csv')
weights
# Out:
#        Donor ID  Weight
# 0    H14.09.001    7.84
# 1    H14.09.002   20.60
# 2    H14.09.003    7.84
# 3    H14.09.004   35.33
# 4    H14.09.005    8.81
# ..          ...     ...
# 102  H15.09.106   37.73
# 103  H15.09.107   14.19
# 104  H15.09.108   82.90
# 105  H15.09.109    9.69
# 106  H15.09.110   98.17
#
# [107 rows x 2 columns]

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------
# absl-py                       2.0.0
# alembic                       1.12.0
# altair                        5.1.2
# anyio                         4.0.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asttokens                     2.4.0
# astunparse                    1.6.3
# async-generator               1.10
# async-lru                     2.0.4
# attrs                         23.1.0
# Babel                         2.13.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.5
# beautifulsoup4                4.12.2
# bleach                        6.1.0
# blinker                       1.6.3
# bokeh                         3.3.0
# boltons                       23.0.0
# Bottleneck                    1.3.7
# Brotli                        1.1.0
# cached-property               1.5.2
# ...

# %% [markdown]
# ONLY ADDED IN CONTAINER
